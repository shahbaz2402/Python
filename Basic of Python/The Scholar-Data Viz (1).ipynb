# %%
import os
os.chdir(r'C:\Users\acer\Desktop\data science file')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\acer\\Desktop\\data science file'

# %%
import pandas as pd

# %%
data = pd.read_csv('DemographicData.csv')

# %%
len(data)
# Out:
# 195

# %%
len(data.columns)
# Out:
# 5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
data.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
data.columns=['CountryName','Countrycode','BirthRate','InternetUsers','IncomeGroup']

# %%
data
# Out:
#               CountryName Countrycode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
data.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
data.isnull().sum()
# Out:
# CountryName      0
# Countrycode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.lmplot(data=data, x = 'InternetUsers', y = 'BirthRate')

# %%
sns.lmplot(data=data, x = 'InternetUsers', y = 'BirthRate' ,fit_reg=False,hue='IncomeGroup')
#

# %%
import os
os.chdir(r'C:\Users\acer\Desktop\data science file')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\acer\\Desktop\\data science file'

# %%
import pandas as pd
flight_data = pd.read_csv(r'C:\Users\acer\Desktop\data science file\flight_data.csv')

# %%
flight_data
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
from dfply import *

# %%
flight_data[['origin','dest','hour']]
# Out:
#        origin dest  hour
# 0         EWR  IAH     5
# 1         LGA  IAH     5
# 2         JFK  MIA     5
# 3         JFK  BQN     5
# 4         LGA  ATL     6
# ...       ...  ...   ...
# 336771    JFK  DCA    14
# 336772    LGA  SYR    22
# 336773    LGA  BNA    12
# 336774    LGA  CLE    11
# 336775    LGA  RDU     8
#
# [336776 rows x 3 columns]

# %%
(flight_data >>
select (X.origin, X.dest, X.hour))
# Out:
#        origin dest  hour
# 0         EWR  IAH     5
# 1         LGA  IAH     5
# 2         JFK  MIA     5
# 3         JFK  BQN     5
# 4         LGA  ATL     6
# ...       ...  ...   ...
# 336771    JFK  DCA    14
# 336772    LGA  SYR    22
# 336773    LGA  BNA    12
# 336774    LGA  CLE    11
# 336775    LGA  RDU     8
#
# [336776 rows x 3 columns]

# %%
(flight_data >>
select (~X.origin, ~X.dest, ~X.hour))

#(~ is used for except this origin, dest, hour data)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum  air_time  distance  \
# ...

# %%
(flight_data >>
mask(X.month==1, X.day==1, X.origin=='JFK',X.hour>10))
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 151  2013      1    1     848.0            1835      853.0    1001.0
# 258  2013      1    1    1059.0            1100       -1.0    1210.0
# 265  2013      1    1    1111.0            1115       -4.0    1222.0
# 266  2013      1    1    1112.0            1100       12.0    1440.0
# 272  2013      1    1    1124.0            1100       24.0    1435.0
# ..    ...    ...  ...       ...             ...        ...       ...
# 832  2013      1    1    2326.0            2130      116.0     131.0
# 833  2013      1    1    2327.0            2250       37.0      32.0
# 835  2013      1    1    2353.0            2359       -6.0     425.0
# 836  2013      1    1    2353.0            2359       -6.0     418.0
# 837  2013      1    1    2356.0            2359       -3.0     425.0
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# ...

# %%
flight_data
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
(flight_data >>
arrange(X.distance,X.hour,ascending=True))
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 275945  2013      7   27       NaN             106        NaN       NaN
# 3083    2013      1    4    1240.0            1200       40.0    1333.0
# 3901    2013      1    5    1155.0            1200       -5.0    1241.0
# 3426    2013      1    4    1829.0            1615      134.0    1937.0
# 10235   2013      1   12    1613.0            1617       -4.0    1708.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 331506  2013      9   25    1001.0            1000        1.0    1508.0
# 333478  2013      9   27     951.0            1000       -9.0    1442.0
# 334406  2013      9   28     955.0            1000       -5.0    1412.0
# 335095  2013      9   29     957.0            1000       -3.0    1405.0
# 336081  2013      9   30     959.0            1000       -1.0    1438.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
#mutate is use to create new column
(flight_data >>
mutate(new_dist = X.distance/1000,carrier_origin =X.carrier + X.origin))
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  ...  tailnum origin dest air_time  \
# ...

# %%
flight_data.origin.unique()
# Out:
# array(['EWR', 'LGA', 'JFK'], dtype=object)

# %%
(flight_data >>
group_by (X.origin) >>
summarise(mean_dist = X.distance.mean()))
# Out:
#   origin    mean_dist
# 0    EWR  1056.742790
# 1    JFK  1266.249077
# 2    LGA   779.835671

# %%
(flight_data >>
mask(X.hour >10) >>
mutate(speed =X.distance/(X.air_time*60))>>
group_by (X.origin)>>
summarise(mean_speed =X.speed.mean())>>
arrange(X.mean_speed,ascending = False))
# Out:
#   origin  mean_speed
# 0    EWR    0.109777
# 1    JFK    0.109427
# 2    LGA    0.107362

# %%
# Removing the duplicate

# %%
df1 = {'Subject': ['Sem1','Sem2','Sem3','Sem4','Sem1','Sem2','Sem3'],
     'Score':[62,47,55,74,32,77,85]}

df2 = {'Subject': ['Sem1','Sem2','Sem3','Sem4'],
     'Score':[90,47,85,74]}

df1 =pd.DataFrame(df1)
df2 =pd.DataFrame(df2)

# %%
df1
# Out:
#   Subject  Score
# 0    Sem1     62
# 1    Sem2     47
# 2    Sem3     55
# 3    Sem4     74
# 4    Sem1     32
# 5    Sem2     77
# 6    Sem3     85

# %%
df2
# Out:
#   Subject  Score
# 0    Sem1     90
# 1    Sem2     47
# 2    Sem3     85
# 3    Sem4     74

# %%
#combined both the column(df1+df2)

# %%
df_union_all = pd.concat([df1,df2])

# %%
df_union_all
# Out:
#   Subject  Score
# 0    Sem1     62
# 1    Sem2     47
# 2    Sem3     55
# 3    Sem4     74
# 4    Sem1     32
# 5    Sem2     77
# 6    Sem3     85
# 0    Sem1     90
# 1    Sem2     47
# 2    Sem3     85
# 3    Sem4     74

# %%
df = df_union_all.drop_duplicates().reset_index()

# %%
df.drop('index',axis=1)
# Out:
#   Subject  Score
# 0    Sem1     62
# 1    Sem2     47
# 2    Sem3     55
# 3    Sem4     74
# 4    Sem1     32
# 5    Sem2     77
# 6    Sem3     85
# 7    Sem1     90
