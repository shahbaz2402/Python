# %%
import pandas as pd

# %%
df = pd.DataFrame({'Country Name' :['USA','India','China'],'Population':[32,132,147]})

# %%
df
# Out:
#   Country Name  Population
# 0          USA          32
# 1        India         132
# 2        China         147

# %%
df.rename({'Country name':'Country_name'},axis='columns')
# Out:
#   Country Name  Population
# 0          USA          32
# 1        India         132
# 2        China         147

# %%
df.rename({'Country name':'country_name'}, axis ='columns')
# Out:
#   Country Name  Population
# 0          USA          32
# 1        India         132
# 2        China         147

# %%
df.columns = df.columns.str.replace('_','$')
df
# Out:
#   Country$Name  Population
# 0          USA          32
# 1        India         132
# 2        China         147

# %%
df.add_prefix('#')
# Out:
#   #Country$Name  #Population
# 0           USA           32
# 1         India          132
# 2         China          147

# %%
df.add_suffix('!')
# Out:
#   Country$Name!  Population!
# 0           USA           32
# 1         India          132
# 2         China          147

# %%
import os
os.chdir(r'C:\Users\acer\Desktop\data science file\tips mul file')

# %%
from glob import glob

# %%
sample =sorted(glob('tips*.csv'))
sample
# Out:
# ['tips 1.csv', 'tips 2.csv', 'tips 3.csv', 'tips 4.csv']

# %%
pd.concat((pd.read_csv(file) for file in sample),ignore_index=True)
# Out:
#     total_bill   tip     sex smoker   day    time  size
# 0        16.99  1.01  Female     No   Sun  Dinner     2
# 1        10.34  1.66    Male     No   Sun  Dinner     3
# 2        21.01  3.50    Male     No   Sun  Dinner     3
# 3        23.68  3.31    Male     No   Sun  Dinner     2
# 4        24.59  3.61  Female     No   Sun  Dinner     4
# 5        25.29  4.71    Male     No   Sun  Dinner     4
# 6         8.77  2.00    Male     No   Sun  Dinner     2
# 7        26.88  3.12    Male     No   Sun  Dinner     4
# 8        26.82  3.10    Male     No   Sun  Dinner     2
# 9        15.04  1.96    Male     No   Sun  Dinner     2
# 10       14.78  3.23    Male     No   Sun  Dinner     2
# 11       10.27  1.71    Male     No   Sun  Dinner     2
# 12       35.26  5.00  Female     No   Sun  Dinner     4
# 13       15.42  1.57    Male     No   Sun  Dinner     2
# 14       18.43  3.00    Male     No   Sun  Dinner     4
# 15       14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
pd.read_clipboard()
# Out:
#    total_bill   tip     sex smoker  day
# 0       15.04  1.96    Male     No  Sun
# 1       14.78  3.23    Male     No  Sun
# 2       10.27  1.71    Male     No  Sun
# 3       35.26  5.00  Female     No  Sun
# 4       15.42  1.57    Male     No  Sun
# 5       18.43  3.00    Male     No  Sun
# 6       14.83  3.02  Female     No  Sun
# 7       21.58  3.92    Male     No  Sun

# %%
a =pd.read_clipboard(sep =',', names =['total_bill','tip','sex','smoker'])

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a.to_csv('scholar.csv')

# %%
pd.read_csv('scholar.csv',index_col=0)
# Out:
#        total_bill     tip sex smoker
# 35.26        5.00  Female  No    Sun
# 15.42        1.57    Male  No    Sun
# 18.43        3.00    Male  No    Sun
# 14.83        3.02  Female  No    Sun
# 21.58        3.92    Male  No    Sun
# 10.33        1.67  Female  No    Sun

# %%
df = pd.DataFrame({'ord id':['ca-1342','tx-3241','mn-5564','fi-5432'],
             'Furniture':[43.55,54.66,34.55,56.54],
             'office supply':[65.44,77.65,45.55,44.33],
             'Technology':[56.55,44.34,66.54,33.32]})

# %%
df
# Out:
#     ord id  Furniture  office supply  Technology
# 0  ca-1342      43.55          65.44       56.55
# 1  tx-3241      54.66          77.65       44.34
# 2  mn-5564      34.55          45.55       66.54
# 3  fi-5432      56.54          44.33       33.32

# %%
df.melt(id_vars='ord id',var_name='category',value_name='Sales')
# Out:
#      ord id       category  Sales
# 0   ca-1342      Furniture  43.55
# 1   tx-3241      Furniture  54.66
# 2   mn-5564      Furniture  34.55
# 3   fi-5432      Furniture  56.54
# 4   ca-1342  office supply  65.44
# 5   tx-3241  office supply  77.65
# 6   mn-5564  office supply  45.55
# 7   fi-5432  office supply  44.33
# 8   ca-1342     Technology  56.55
# 9   tx-3241     Technology  44.34
# 10  mn-5564     Technology  66.54
# 11  fi-5432     Technology  33.32

# %%
import pandas as pd
from pandas import *

# %%
df = pd.DataFrame({'Gender':['Male','Female','Male','Female'],
              'Age':[12,13,21,19]})

# %%
df
# Out:
#    Gender  Age
# 0    Male   12
# 1  Female   13
# 2    Male   21
# 3  Female   19

# %%
tips = pd.read_csv('tips1.csv')

# %%
tips['running_total']=tips.total_bill.cumsum()

# %%
tips.sex +'-'+ tips.smoker
# Out:
# 0    Female-No
# 1      Male-No
# 2      Male-No
# 3      Male-No
# 4    Female-No
# 5      Male-No
# 6      Male-No
# 7      Male-No
# 8      Male-No
# dtype: object

# %%
pd.read_csv('tips1.csv')
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       26.82  3.10    Male     No  Sun  Dinner     2

# %%
df = pd.read_csv('tips1.csv',usecols=['total_bill','smoker','size'])

# %%
avg_sales = tips.total_bill.mean()

# %%
avg_sales
# Out:
# 20.485555555555557

# %%
tips.query('total_bill > @avg_sales')
# Out:
#    total_bill   tip     sex smoker  day    time  size  running_total
# 2       21.01  3.50    Male     No  Sun  Dinner     3          48.34
# 3       23.68  3.31    Male     No  Sun  Dinner     2          72.02
# 4       24.59  3.61  Female     No  Sun  Dinner     4          96.61
# 5       25.29  4.71    Male     No  Sun  Dinner     4         121.90
# 7       26.88  3.12    Male     No  Sun  Dinner     4         157.55
# 8       26.82  3.10    Male     No  Sun  Dinner     2         184.37

# %%
tips[tips['total_bill'] > avg_sales]
# Out:
#    total_bill   tip     sex smoker  day    time  size  running_total
# 2       21.01  3.50    Male     No  Sun  Dinner     3          48.34
# 3       23.68  3.31    Male     No  Sun  Dinner     2          72.02
# 4       24.59  3.61  Female     No  Sun  Dinner     4          96.61
# 5       25.29  4.71    Male     No  Sun  Dinner     4         121.90
# 7       26.88  3.12    Male     No  Sun  Dinner     4         157.55
# 8       26.82  3.10    Male     No  Sun  Dinner     2         184.37

# %%
#Rating Ordinal data
#Excellent
#good
#Average
#Poor

#Sameday
#1st class
#2nd class
#Standard Class

# %%
df= pd.DataFrame({'Order id':[10,11,12,13,15,16],
             'Manufactuer':['A','A','B','D','C','D'],
             'Shipmode':['Sameday','Standardclass','1st Class','2nd Class','1st Class','SameDay']})

# %%
df
# Out:
#    Order id Manufactuer       Shipmode
# 0        10           A        Sameday
# 1        11           A  Standardclass
# 2        12           B      1st Class
# 3        13           D      2nd Class
# 4        15           C      1st Class
# 5        16           D        SameDay

# %%
from pandas.api.types import CategoricalDtype

# %%
type =CategoricalDtype(['Standard Class','2nd Class','1st Class','Same Day'], ordered =True)

# %%
type
# Out:
# CategoricalDtype(categories=['Standard Class', '2nd Class', '1st Class', 'Same Day'], ordered=True)

# %%
df['Shipmode'] = df.Shipmode.astype(type)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
# Order id       6 non-null int64
# Manufactuer    6 non-null object
# Shipmode       3 non-null category
# dtypes: category(1), int64(1), object(1)
# memory usage: 422.0+ bytes

# %%
df.Shipmode
# Out:
# 0          NaN
# 1          NaN
# 2    1st Class
# 3    2nd Class
# 4    1st Class
# 5          NaN
# Name: Shipmode, dtype: category
# Categories (4, object): [Standard Class < 2nd Class < 1st Class < Same Day]

# %%
df.sort_values('Shipmode',ascending=0)
# Out:
#    Order id Manufactuer   Shipmode
# 2        12           B  1st Class
# 4        15           C  1st Class
# 3        13           D  2nd Class
# 0        10           A        NaN
# 1        11           A        NaN
# 5        16           D        NaN

# %%
df[df.Shipmode>='1st Class']
# Out:
#    Order id Manufactuer   Shipmode
# 2        12           B  1st Class
# 4        15           C  1st Class

# %%
tips
# Out:
#    total_bill   tip     sex smoker  day    time  size  running_total
# 0       16.99  1.01  Female     No  Sun  Dinner     2          16.99
# 1       10.34  1.66    Male     No  Sun  Dinner     3          27.33
# 2       21.01  3.50    Male     No  Sun  Dinner     3          48.34
# 3       23.68  3.31    Male     No  Sun  Dinner     2          72.02
# 4       24.59  3.61  Female     No  Sun  Dinner     4          96.61
# 5       25.29  4.71    Male     No  Sun  Dinner     4         121.90
# 6        8.77  2.00    Male     No  Sun  Dinner     2         130.67
# 7       26.88  3.12    Male     No  Sun  Dinner     4         157.55
# 8       26.82  3.10    Male     No  Sun  Dinner     2         184.37

# %%
tips.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_52a080c6_f39a_11ea_b90f_f8cab8661d98" ><thead>    <tr>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>        <th class="col_heading level0 col7" >running_total</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_52a080c6_f39a_11ea_b90f_f8cab8661d98row0_col0" class="data row0 col0" >16.99</td>
#                         <td id="T_52a080c6_f39a_11ea_b90f_f8cab8661d98row0_col1" class="data row0 col1" >1.01</td>
#                         <td id="T_52a080c6_f39a_11ea_b90f_f8cab8661d98row0_col2" class="data row0 col2" >Female</td>
# ...

# %%
tips.style.set_caption('This is the tips table with all information')
# Out:
# <style  type="text/css" >
# </style><table id="T_8d9991e8_f39a_11ea_8f6c_f8cab8661d98" ><caption>This is the tips table with all information</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>        <th class="col_heading level0 col7" >running_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8d9991e8_f39a_11ea_8f6c_f8cab8661d98level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8d9991e8_f39a_11ea_8f6c_f8cab8661d98row0_col0" class="data row0 col0" >16.99</td>
# ...

# %%
tips.style.hide_index().set_caption('This is the tips table')
# Out:
# <style  type="text/css" >
# </style><table id="T_b3be70f4_f39a_11ea_980e_f8cab8661d98" ><caption>This is the tips table</caption><thead>    <tr>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>        <th class="col_heading level0 col7" >running_total</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_b3be70f4_f39a_11ea_980e_f8cab8661d98row0_col0" class="data row0 col0" >16.99</td>
#                         <td id="T_b3be70f4_f39a_11ea_980e_f8cab8661d98row0_col1" class="data row0 col1" >1.01</td>
# ...

# %%
tips.loc[2,'sex']
# Out:
# 'Male'

# %%
tips
# Out:
#    total_bill   tip     sex smoker  day    time  size  running_total
# 0       16.99  1.01  Female     No  Sun  Dinner     2          16.99
# 1       10.34  1.66    Male     No  Sun  Dinner     3          27.33
# 2       21.01  3.50    Male     No  Sun  Dinner     3          48.34
# 3       23.68  3.31    Male     No  Sun  Dinner     2          72.02
# 4       24.59  3.61  Female     No  Sun  Dinner     4          96.61
# 5       25.29  4.71    Male     No  Sun  Dinner     4         121.90
# 6        8.77  2.00    Male     No  Sun  Dinner     2         130.67
# 7       26.88  3.12    Male     No  Sun  Dinner     4         157.55
# 8       26.82  3.10    Male     No  Sun  Dinner     2         184.37

# %%
tips.loc[2,tips.columns[1]]
# Out:
# 3.5

# %%
tips
# Out:
#    total_bill   tip     sex smoker  day    time  size  running_total
# 0       16.99  1.01  Female     No  Sun  Dinner     2          16.99
# 1       10.34  1.66    Male     No  Sun  Dinner     3          27.33
# 2       21.01  3.50    Male     No  Sun  Dinner     3          48.34
# 3       23.68  3.31    Male     No  Sun  Dinner     2          72.02
# 4       24.59  3.61  Female     No  Sun  Dinner     4          96.61
# 5       25.29  4.71    Male     No  Sun  Dinner     4         121.90
# 6        8.77  2.00    Male     No  Sun  Dinner     2         130.67
# 7       26.88  3.12    Male     No  Sun  Dinner     4         157.55
# 8       26.82  3.10    Male     No  Sun  Dinner     2         184.37

# %%
tips.loc[tips.index[2],'sex']
# Out:
# 'Male'

# %%
tips.iloc[tips.index.get_loc(2),1]
# Out:
# 3.5

# %%
tips.iloc[2,tips.columns.get_loc('sex')]
# Out:
# 'Male'

# %%
df = pd.DataFrame({'Daily_Sales':[43,24,54,65,42,47],'Weekly Sales':[41,22,33,44,55,66]})

# %%
df
# Out:
#    Daily_Sales  Weekly Sales
# 0           43            41
# 1           24            22
# 2           54            33
# 3           65            44
# 4           42            55
# 5           47            66

# %%
df.query('Daily_Sales>=10')
# Out:
#    Daily_Sales  Weekly Sales
# 0           43            41
# 1           24            22
# 2           54            33
# 3           65            44
# 4           42            55
# 5           47            66

# %%
df.query('`Weekly Sales`>16')
# Out:
#    Daily_Sales  Weekly Sales
# 0           43            41
# 1           24            22
# 2           54            33
# 3           65            44
# 4           42            55
# 5           47            66

# %%
df = pd.DataFrame({'Status':['Order date','Ship Date','Delivery Date'],'Month':[4,4,6],'Day':[25,28,19],'Year':[2020,2020,2020]})

# %%
df
# Out:
#           Status  Month  Day  Year
# 0     Order date      4   25  2020
# 1      Ship Date      4   28  2020
# 2  Delivery Date      6   19  2020

# %%
df['Date'] = pd.to_datetime(df[['Month','Day','Year']])

# %%
df
# Out:
#           Status  Month  Day  Year       Date
# 0     Order date      4   25  2020 2020-04-25
# 1      Ship Date      4   28  2020 2020-04-28
# 2  Delivery Date      6   19  2020 2020-06-19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
# Status    3 non-null object
# Month     3 non-null int64
# Day       3 non-null int64
# Year      3 non-null int64
# Date      3 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 248.0+ bytes

# %%
raw_data ={'cust_id':[1,2,3,4],'FN':['A','B','C','D'],'LN':['T','R','Y','L']}

raw_data1 ={'cust_id':[1,2,3,5],'Sub':['Py','R','Ta','BI']}

# %%
b =pd.DataFrame(raw_data1)

# %%
a =pd.DataFrame(raw_data)

# %%
a
# Out:
#    cust_id FN LN
# 0        1  A  T
# 1        2  B  R
# 2        3  C  Y
# 3        4  D  L

# %%
b
# Out:
#    cust_id Sub
# 0        1  Py
# 1        2   R
# 2        3  Ta
# 3        5  BI

# %%
pd.merge(a,b,on='cust_id',how='right',indicator=True)
# Out:
#    cust_id   FN   LN Sub      _merge
# 0        1    A    T  Py        both
# 1        2    B    R   R        both
# 2        3    C    Y  Ta        both
# 3        5  NaN  NaN  BI  right_only

# %%
tips
# Out:
#    total_bill   tip     sex smoker  day    time  size  running_total
# 0       16.99  1.01  Female     No  Sun  Dinner     2          16.99
# 1       10.34  1.66    Male     No  Sun  Dinner     3          27.33
# 2       21.01  3.50    Male     No  Sun  Dinner     3          48.34
# 3       23.68  3.31    Male     No  Sun  Dinner     2          72.02
# 4       24.59  3.61  Female     No  Sun  Dinner     4          96.61
# 5       25.29  4.71    Male     No  Sun  Dinner     4         121.90
# 6        8.77  2.00    Male     No  Sun  Dinner     2         130.67
# 7       26.88  3.12    Male     No  Sun  Dinner     4         157.55
# 8       26.82  3.10    Male     No  Sun  Dinner     2         184.37

# %%
dict={'total_bill':'${:.2f}','tip':'@{:.2f}'}

# %%
tips.style.format(dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_c3035a80_f3a4_11ea_aeff_f8cab8661d98" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>        <th class="col_heading level0 col7" >running_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c3035a80_f3a4_11ea_aeff_f8cab8661d98level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c3035a80_f3a4_11ea_aeff_f8cab8661d98row0_col0" class="data row0 col0" >$16.99</td>
#                         <td id="T_c3035a80_f3a4_11ea_aeff_f8cab8661d98row0_col1" class="data row0 col1" >@1.01</td>
# ...

# %%
(tips.style.highlight_min('total_bill',color='Red').highlight_max('total_bill',color='Green'))
# Out:
# <style  type="text/css" >
#     #T_31d53602_f3a5_11ea_9c14_f8cab8661d98row6_col0 {
#             background-color:  Red;
#             : ;
#         }    #T_31d53602_f3a5_11ea_9c14_f8cab8661d98row7_col0 {
#             : ;
#             background-color:  Green;
#         }</style><table id="T_31d53602_f3a5_11ea_9c14_f8cab8661d98" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>        <th class="col_heading level0 col7" >running_total</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
tips.style.background_gradient(subset='tip',cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_59901736_f3a5_11ea_a4d0_f8cab8661d98row0_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_59901736_f3a5_11ea_a4d0_f8cab8661d98row1_col1 {
#             background-color:  #daf0d4;
#             color:  #000000;
#         }    #T_59901736_f3a5_11ea_a4d0_f8cab8661d98row2_col1 {
#             background-color:  #359e53;
#             color:  #000000;
#         }    #T_59901736_f3a5_11ea_a4d0_f8cab8661d98row3_col1 {
#             background-color:  #42ab5d;
#             color:  #000000;
#         }    #T_59901736_f3a5_11ea_a4d0_f8cab8661d98row4_col1 {
#             background-color:  #2f974e;
#             color:  #000000;
#         }    #T_59901736_f3a5_11ea_a4d0_f8cab8661d98row5_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_59901736_f3a5_11ea_a4d0_f8cab8661d98row6_col1 {
#             background-color:  #c2e7bb;
#             color:  #000000;
# ...

# %%
tips.style.bar('total_bill',color='green')
# Out:
# <style  type="text/css" >
#     #T_7afdd376_f3a5_11ea_96ec_f8cab8661d98row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 45.4%, transparent 45.4%);
#         }    #T_7afdd376_f3a5_11ea_96ec_f8cab8661d98row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 8.7%, transparent 8.7%);
#         }    #T_7afdd376_f3a5_11ea_96ec_f8cab8661d98row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 67.6%, transparent 67.6%);
#         }    #T_7afdd376_f3a5_11ea_96ec_f8cab8661d98row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 82.3%, transparent 82.3%);
#         }    #T_7afdd376_f3a5_11ea_96ec_f8cab8661d98row4_col0 {
#             width:  10em;
#              height:  80%;
# ...
